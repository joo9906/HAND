# %% [markdown]
# # KcELECTRA 모델 경량화 및 최적화

# %% [markdown]
# 1. F16으로 경량화
# 2. bitsandbytes 8bit
#
# 추론 속도 자체는 충분히 빨라서 굳이 최적화를 해야할 지 모르겠음. 일단 time으로 찍어 볼 예정.

# %%
# !pip show safetensors
# Out:
# Name: safetensors
# Version: 0.6.2
# Summary:
# Home-page: https://github.com/huggingface/safetensors
# Author:
# Author-email: Nicolas Patry <patry.nicolas@protonmail.com>
# License:
# Location: c:\users\ssafy\desktop\wang\kcvenv\lib\site-packages
# Requires:
# Required-by: accelerate, peft, transformers
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\ssafy\desktop\wang\kcvenv\lib\site-packages)

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer, BitsAndBytesConfig
import torch, os

model_path = r"C:\Users\SSAFY\Desktop\WANG\S13P31A106\ai\Classifier_Model"
dst_path = "./best_model_INT8"

# ✅ bitsandbytes 설정 (8비트 양자화)
bnb_config = BitsAndBytesConfig(
    load_in_8bit=True,             # 8비트 양자화 활성화
    llm_int8_threshold=6.0,        # outlier threshold (기본값 6.0)
    llm_int8_has_fp16_weight=False # 완전 INT8로 저장
)

# ✅ 모델 로드 + 양자화 적용
model = AutoModelForSequenceClassification.from_pretrained(
    model_path,
    quantization_config=bnb_config,
    device_map="auto"   # 자동으로 GPU/CPU 분배
)

# ✅ 저장
model.save_pretrained(dst_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)
tokenizer.save_pretrained(dst_path)

print("✅ INT8 모델 변환 완료:", dst_path)
# Out:
# ✅ INT8 모델 변환 완료: ./best_model_INT8

# %%
# 감정 카테고리 (모델의 class 순서)
CATEGORIES = [
    "happy",
    "embarrass",
    "anger",
    "unrest",
    "damaged",
    "sadness",
]

# 이건 실제 csv에서 뽑아올 것.
label_map = {
    "기쁨": 0,     # happy
    "당황": 1,     # embarrass
    "분노": 2,     # anger
    "불안": 3,     # unrest
    "상처": 4,     # damaged
    "슬픔": 5,     # sadness
}

NUM_LABELS = len(CATEGORIES)

import re
import emoji
from soynlp.normalizer import repeat_normalize

pattern = re.compile(f'[^ .,?!/@$%~％·∼()\x00-\x7Fㄱ-ㅣ가-힣]+')
url_pattern = re.compile(
    r'https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)')

def clean(x): 
    x = pattern.sub(' ', x)
    x = emoji.replace_emoji(x, replace='') #emoji 삭제
    x = url_pattern.sub('', x)
    x = x.strip()
    x = repeat_normalize(x, num_repeats=2)
    return x

# %%
import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch.nn.functional as F
import os
import time

# 모델이랑 토크나이저 불러오기.
# MODEL_DIR = r"C:\Users\SSAFY\Desktop\WANG\S13P31A106\ai\best_model_INT8"
MODEL_DIR = r"C:\Users\SSAFY\Desktop\WANG\S13P31A106\ai\Classifier_Model"
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR)
model = AutoModelForSequenceClassification.from_pretrained(MODEL_DIR)
model.eval().to("cpu")

# model = AutoModelForSequenceClassification.from_pretrained(MODEL_DIR, device_map="cpu")

def predict_emotion(texts):
    if isinstance(texts, str):
        texts = [texts]

    device = "cuda" if torch.cuda.get_device_name(0) else "cpu"
    inputs = tokenizer(
        texts,
        padding=True,
        truncation=True,
        max_length=64,
        return_tensors="pt"
    ).to(device)

    with torch.no_grad():
        outputs = model(**inputs)
        probs = F.softmax(outputs.logits, dim=-1)
        preds = probs.argmax(dim=-1)
    
    results = {
        "text": clean(texts),
        "pred_label": CATEGORIES[preds.item()],
        "probabilities": {CATEGORIES[j]: round(probs[0][j].item(), 4) for j in range(len(CATEGORIES))}
        }
    
    #여러 문장인 경우
    # for i, text in enumerate(texts):
    #     results.append({
    #         "text": clean(text),
    #         "pred_label": CATEGORIES[preds[i].item()],
    #         "probabilities": {CATEGORIES[j]: round(probs[i][j].item(), 4) for j in range(len(CATEGORIES))}
    #     })
    return results

# %%
import time
import mlflow

sample = ["요즘은 그냥 웃으려고 해, 웃고있으면 괜찮으니까"]
mlflow.set_tracking_uri(r"file:\\\C:\Users\SSAFY\Desktop\WANG\S13P31A106\ai\mlruns")

with mlflow.start_run(run_name="inference_time_last"):
    try:
        times = []
        for i, text in enumerate(sample):
            start = time.time()
            result = predict_emotion(text)
            end = time.time()
            infer_time = end - start
            times.append(infer_time)
            
            print(f'타겟 문장은 {text}, 감정 분석은 {result["probabilities"]}, 걸린 시간은{infer_time}')
            
            mlflow.log_metric("inference_time", infer_time, step=i)
            
        avg_time = sum(times) / len(times)
        mlflow.log_metric("avg_inference_time", avg_time)
        print(f"평균 추론 시간: {avg_time:.3f}초")
    finally:
        mlflow.end_run()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 import time
# ----> 2 import mlflow
#       4 sample = ["요즘은 그냥 웃으려고 해, 웃고있으면 괜찮으니까"]
#       5 mlflow.set_tracking_uri(r"file:\\\C:\Users\SSAFY\Desktop\WANG\S13P31A106\ai\mlruns")
#
# File c:\Users\SSAFY\Desktop\WANG\Kcvenv\lib\site-packages\mlflow\__init__.py:44
#      41     mlflow.mismatch._check_version_mismatch()
#      43 if not IS_TRACING_SDK_ONLY:
# ---> 44     from mlflow import (
#      45         artifacts,  # noqa: F401
#      46         client,  # noqa: F401
#      47         config,  # noqa: F401
#      48         data,  # noqa: F401
#      49         exceptions,  # noqa: F401
#      50         genai,  # noqa: F401
#      51         models,  # noqa: F401
#      52         projects,  # noqa: F401
#      53         tracking,  # noqa: F401
#      54     )
#      56 from mlflow import tracing  # noqa: F401
#      57 from mlflow.environment_variables import MLFLOW_CONFIGURE_LOGGING
#
# File c:\Users\SSAFY\Desktop\WANG\Kcvenv\lib\site-packages\mlflow\genai\__init__.py:1
# ----> 1 from mlflow.genai import (
#       2     datasets,
#       3     judges,
#       4     scorers,
#       5 )
#       6 from mlflow.genai.datasets import (
#       7     create_dataset,
#       8     delete_dataset,
#    (...)
#      12     set_dataset_tags,
#      13 )
#      14 from mlflow.genai.evaluation import evaluate, to_predict_fn
#
# File c:\Users\SSAFY\Desktop\WANG\Kcvenv\lib\site-packages\mlflow\genai\judges\__init__.py:4
#       2 from mlflow.genai.judges import utils  # noqa: F401
#       3 from mlflow.genai.judges.base import AlignmentOptimizer, Judge
# ----> 4 from mlflow.genai.judges.builtin import (
#       5     is_context_relevant,
#       6     is_context_sufficient,
#       7     is_correct,
#       8     is_grounded,
#       9     is_safe,
#      10     meets_guidelines,
#      11 )
#      12 from mlflow.genai.judges.custom_prompt_judge import custom_prompt_judge
#      13 from mlflow.genai.judges.make_judge import make_judge
#
# File c:\Users\SSAFY\Desktop\WANG\Kcvenv\lib\site-packages\mlflow\genai\judges\builtin.py:5
#       2 from typing import Any
#       4 from mlflow.entities.assessment import Feedback
# ----> 5 from mlflow.genai.judges.prompts.relevance_to_query import RELEVANCE_TO_QUERY_ASSESSMENT_NAME
#       6 from mlflow.genai.judges.utils import CategoricalRating, get_default_model, invoke_judge_model
#       7 from mlflow.utils.docstring_utils import format_docstring
#
# File c:\Users\SSAFY\Desktop\WANG\Kcvenv\lib\site-packages\mlflow\genai\judges\prompts\relevance_to_query.py:1
# ----> 1 from mlflow.genai.prompts.utils import format_prompt
#       3 # NB: User-facing name for the is_context_relevant assessment.
#       4 RELEVANCE_TO_QUERY_ASSESSMENT_NAME = "relevance_to_context"
#
# File c:\Users\SSAFY\Desktop\WANG\Kcvenv\lib\site-packages\mlflow\genai\prompts\__init__.py:7
#       3 from typing import Any
#       5 from pydantic import BaseModel
# ----> 7 import mlflow.tracking._model_registry.fluent as registry_api
#       8 from mlflow.entities.model_registry.prompt import Prompt
#       9 from mlflow.entities.model_registry.prompt_version import PromptVersion
#
# File c:\Users\SSAFY\Desktop\WANG\Kcvenv\lib\site-packages\mlflow\tracking\_model_registry\fluent.py:20
#      15 from mlflow.environment_variables import (
#      16     MLFLOW_PRINT_MODEL_URLS_ON_CREATION,
#      17     MLFLOW_PROMPT_CACHE_MAX_SIZE,
#      18 )
#      19 from mlflow.exceptions import MlflowException
# ---> 20 from mlflow.models.model import MLMODEL_FILE_NAME
#      21 from mlflow.prompt.registry_utils import parse_prompt_name_or_uri, require_prompt_registry
#      22 from mlflow.protos.databricks_pb2 import (
#      23     ALREADY_EXISTS,
#      24     NOT_FOUND,
#      25     RESOURCE_ALREADY_EXISTS,
#      26     ErrorCode,
#      27 )
#
# File c:\Users\SSAFY\Desktop\WANG\Kcvenv\lib\site-packages\mlflow\models\__init__.py:44
#      34 from mlflow.models.evaluation import (
#      35     EvaluationArtifact,
#      36     EvaluationMetric,
#    (...)
#      41     make_metric,
#      42 )
#      43 from mlflow.models.flavor_backend import FlavorBackend
# ---> 44 from mlflow.models.model import Model, get_model_info, set_model, update_model_requirements
#      45 from mlflow.models.model_config import ModelConfig
#      46 from mlflow.models.python_api import build_docker
#
# File c:\Users\SSAFY\Desktop\WANG\Kcvenv\lib\site-packages\mlflow\models\model.py:394
#     388         """
#     389         Returns the name of the logged model.
#     390         """
#     391         return self._logged_model.name if self._logged_model else None
# --> 394 class Model:
#     395     """
#     396     An MLflow Model that can support multiple model flavors. Provides APIs for implementing
#     397     new Model flavors.
#     398     """
#     400     def __init__(
#     401         self,
#     402         artifact_path=None,
#    (...)
#     418     ):
#     419         # store model id instead of run_id and path to avoid confusion when model gets exported
#
# File c:\Users\SSAFY\Desktop\WANG\Kcvenv\lib\site-packages\mlflow\models\model.py:409, in Model()
#     394 class Model:
#     395     """
#     396     An MLflow Model that can support multiple model flavors. Provides APIs for implementing
#     397     new Model flavors.
#     398     """
#     400     def __init__(
#     401         self,
#     402         artifact_path=None,
#     403         run_id=None,
#     404         utc_time_created=None,
#     405         flavors=None,
#     406         signature=None,  # ModelSignature
#     407         saved_input_example_info: dict[str, Any] | None = None,
#     408         model_uuid: str | Callable[[], str] | None = lambda: uuid.uuid4().hex,
# --> 409         mlflow_version: str | None = mlflow.version.VERSION,
#     410         metadata: dict[str, Any] | None = None,
#     411         model_size_bytes: int | None = None,
#     412         resources: str | list[Resource] | None = None,
#     413         env_vars: list[str] | None = None,
#     414         auth_policy: AuthPolicy | None = None,
#     415         model_id: str | None = None,
#     416         prompts: list[str] | None = None,
#     417         **kwargs,
#     418     ):
#     419         # store model id instead of run_id and path to avoid confusion when model gets exported
#     420         self.run_id = run_id
#     421         self.artifact_path = artifact_path
#
# AttributeError: partially initialized module 'mlflow' has no attribute 'version' (most likely due to a circular import)

# %%
import torch
import bitsandbytes as bnb

print("Torch CUDA available:", torch.cuda.is_available())
print("Torch CUDA version:", torch.version.cuda)
print("GPU name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
print("Bitsandbytes version:", bnb.__version__)
# Out:
# Torch CUDA available: True
# Torch CUDA version: 12.1
# GPU name: NVIDIA GeForce RTX 4050 Laptop GPU
# Bitsandbytes version: 0.43.2

# %% [markdown]
# # 경량화 평가
